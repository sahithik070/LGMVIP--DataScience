# %% [markdown]
# <a href="https://colab.research.google.com/github/sahithik070/LGMVIP--DataScience/blob/main/pypencilsketch.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install opencv-python
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import cv2
photo = cv2.imread('/content/alluarjun.jpeg')

# %%
import time
start = time.time()

# %% [markdown]
# #Internal Mechanism of Model

# %%
gray = cv2.cvtColor(photo, cv2.COLOR_BGR2GRAY)
from google.colab.patches import cv2_imshow
cv2_imshow(gray)
# Out:
# <PIL.Image.Image image mode=L size=264x191 at 0x7F76D28AB100>

# %%
invert = cv2.bitwise_not(gray)
cv2_imshow(invert)
# Out:
# <PIL.Image.Image image mode=L size=264x191 at 0x7F76D28ABAF0>

# %%
blur = cv2.GaussianBlur(invert, (15, 15), 0)
cv2_imshow(blur)
# Out:
# <PIL.Image.Image image mode=L size=264x191 at 0x7F76D28ABFA0>

# %%
invertblur = cv2.bitwise_not(blur)
cv2_imshow(invertblur)
# Out:
# <PIL.Image.Image image mode=L size=264x191 at 0x7F76AC883D60>

# %%
sketch = cv2.divide(gray, invertblur, scale= 250.0)
cv2_imshow(sketch)
# Out:
# <PIL.Image.Image image mode=L size=264x191 at 0x7F76AC883A60>

# %%
from google.colab.patches import cv2_imshow
cv2.imwrite('output.png', sketch)
# Out:
# True

# %% [markdown]
# #For time taken calculation

# %%
end = time.time()
print(end-start)
# Out:
# 1.0157806873321533
